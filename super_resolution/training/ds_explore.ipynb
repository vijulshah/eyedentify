# %%
import cv2
import numpy as np
import mediapipe as mp
import matplotlib.pyplot as plt
# Out:
# 2024-09-03 18:00:32.963698: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-03 18:00:32.963808: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-03 18:00:32.967220: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-03 18:00:32.989121: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
output_folder = "/home/vshah/Documents/Uni/Thesis_Cluster/pupil-size-estimation-with-super-resolution/SR_training/HAT/datasets"

# %%
IMAGE_FILE = "/home/vshah/Documents/Uni/Thesis_SR_Data/celeba_hq_256/00006.jpg"
frame = cv2.imread(IMAGE_FILE)
rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_frame)
plt.axis('off')
plt.show()

# %%
IMAGE_FILE = "/home/vshah/Documents/Uni/Thesis_SR_Data/celebahq_1024/000016.jpg"
frame = cv2.imread(IMAGE_FILE)
rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_frame)
plt.axis('off')
plt.show()

# %%
IMAGE_FILE_2 = "/home/vshah/Documents/Uni/Thesis_SR_Data/ffhq_512/00011.png"
frame2 = cv2.imread(IMAGE_FILE_2)
rgb_frame2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_frame2)
plt.axis('off')
plt.show()
